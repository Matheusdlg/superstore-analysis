# %%
# Montagem do Google drive para ter acesso ao Dataset
from google.colab import drive
drive.mount('/content/drive')

# %%
# importando as bibliotecas que vou usar no projeto
import pandas as pd
import matplotlib.pyplot as plt

# %%
# carregando a base da Superstore
# usei encoding windows-1252 porque deu erro de leitura com o padrão utf-8
df = pd.read_csv('/content/drive/MyDrive/Projeto 03 - Superstore/Sample - Superstore.csv', encoding='windows-1252')

df

# %%
# olhando as primeiras linhas pra entender as colunas
df.head()

# %%
# tamanho do dataset e tipos de cada coluna
print(df.shape)
print(df.info())

# %%
# checando estatísticas gerais, se tem nulo e se tem linha duplicada
print(df.describe())
print(df.isnull().sum())
print(df.duplicated().sum())

# não tem nulo nem duplicado, então não precisei tratar nada aqui

# %%
# as datas estavam como string, precisei converter pra datetime
# pra depois conseguir tirar ano e mês
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

df.info()

# %%
# vendo o total de vendas e de lucro da empresa inteira, só pra ter uma noção geral
print(df['Sales'].sum())
print(df['Profit'].sum())

#df['Order ID'].unique() # Mostra quais são
print(f'Quantidade de pedidos diferentes (Order ids únicos): {df["Order ID"].nunique()}') # Mostra a quantidade de valores únicos
# o Order ID repete porque um mesmo pedido pode ter mais de um produto
